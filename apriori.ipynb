# %% [markdown]
# ## Algoritmo Apriori

# %% [markdown]
# ### Carga das bibliotecas

# %%
# Bibliotecas
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# ### Base de Dados

# %%
# --- 1. Leitura dos dados ---

df = pd.read_csv('vendas_calcados.csv')

# %% [markdown]
# ### Visualização do Dataframe

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'vendedor', 'produto', 'cliente', 'cidade', 'mês'], dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                                 vendedor  \
# 0           0  V.V. REPRESENTACAO COM DE CALCADOS LTDA
# 1           1  V.V. REPRESENTACAO COM DE CALCADOS LTDA
# 2           2  V.V. REPRESENTACAO COM DE CALCADOS LTDA
# 3           3  V.V. REPRESENTACAO COM DE CALCADOS LTDA
# 4           4  V.V. REPRESENTACAO COM DE CALCADOS LTDA
#
#                    produto                               cliente  \
# 0        MOCASSIM FEMININO  A. A. MUSTAFA COM DE MODAS LTDA  EPP
# 1        MOCASSIM FEMININO  A. A. MUSTAFA COM DE MODAS LTDA  EPP
# 2  RECEM NASCIDO ALGO MAIS  A. A. MUSTAFA COM DE MODAS LTDA  EPP
# 3       MOCASSIM MASCULINO  A. A. MUSTAFA COM DE MODAS LTDA  EPP
# 4       MOCASSIM MASCULINO  A. A. MUSTAFA COM DE MODAS LTDA  EPP
#
#            cidade       mês
# 0  SAO PAULO - SP   Janeiro
# 1  SAO PAULO - SP   Janeiro
# 2  SAO PAULO - SP  Novembro
# 3  SAO PAULO - SP   Janeiro
# 4  SAO PAULO - SP   Janeiro

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# vendedor      0
# produto       0
# cliente       0
# cidade        0
# mês           0
# dtype: int64

# %%
# --- 2. Mapeamento de meses para trimestres ---
mes_para_trimestre = {
    'Janeiro': 'T1', 'Fevereiro': 'T1', 'Março': 'T1',
    'Abril': 'T2', 'Maio': 'T2', 'Junho': 'T2',
    'Julho': 'T3', 'Agosto': 'T3', 'Setembro': 'T3',
    'Outubro': 'T4', 'Novembro': 'T4', 'Dezembro': 'T4'
}

df['trimestre'] = df['mês'].map(mes_para_trimestre)

# %%
df.head()
# Out:
#    Unnamed: 0                                 vendedor  \
# 0           0  V.V. REPRESENTACAO COM DE CALCADOS LTDA
# 1           1  V.V. REPRESENTACAO COM DE CALCADOS LTDA
# 2           2  V.V. REPRESENTACAO COM DE CALCADOS LTDA
# 3           3  V.V. REPRESENTACAO COM DE CALCADOS LTDA
# 4           4  V.V. REPRESENTACAO COM DE CALCADOS LTDA
#
#                    produto                               cliente  \
# 0        MOCASSIM FEMININO  A. A. MUSTAFA COM DE MODAS LTDA  EPP
# 1        MOCASSIM FEMININO  A. A. MUSTAFA COM DE MODAS LTDA  EPP
# 2  RECEM NASCIDO ALGO MAIS  A. A. MUSTAFA COM DE MODAS LTDA  EPP
# 3       MOCASSIM MASCULINO  A. A. MUSTAFA COM DE MODAS LTDA  EPP
# 4       MOCASSIM MASCULINO  A. A. MUSTAFA COM DE MODAS LTDA  EPP
#
#            cidade       mês trimestre
# 0  SAO PAULO - SP   Janeiro        T1
# 1  SAO PAULO - SP   Janeiro        T1
# 2  SAO PAULO - SP  Novembro        T4
# 3  SAO PAULO - SP   Janeiro        T1
# 4  SAO PAULO - SP   Janeiro        T1

# %% [markdown]
# ### Escolha das colunas para o Apriori

# %%
# --- 3. Agrupamento por cliente + trimestre ---
grouped = df.groupby(['cliente', 'trimestre'])['produto'].apply(list).reset_index()

# Guarda o conjunto de dados em Html
grouped.to_html('dados.html')

# Guarda o conjunto de dados em csv
grouped.to_csv('dados.csv')

# %%
grouped.head()
# Out:
#                          cliente trimestre  \
# 0  2M CALCADOS E CONFECCOES LTDA        T2
# 1       3M - LOJAS FREE - EIRELI        T3
# 2   A A DOS SANTOS & CIA LTDA ME        T2
# 3       A ALMEIDA COSTA SUBRINHO        T1
# 4       A ALMEIDA COSTA SUBRINHO        T3
#
#                                              produto
# 0  [CALCADO KLIN TENIS FEMININO ALGODAO DOCE 115,...
# 1  [CALCADO KLIN MOCASSIM MASCULINO RECEM NASCIDO...
# 2  [CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054, ...
# 3  [MOCASSIM MASCULINO, MOCASSIM MASCULINO, SANDA...
# 4  [CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO...

# %% [markdown]
# ### Execução do Apriori

# %%
# --- 4. Criar lista de transações (lista de listas) ---
list_of_lists = grouped['produto'].tolist()

# --- 5. Transformação binária com TransactionEncoder ---
te = TransactionEncoder()
te_ary = te.fit(list_of_lists).transform(list_of_lists)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# --- 6. Execução do Apriori ---
support = 0.01
confidence = 0.85

frequent_item_sets = apriori(df_encoded, min_support=support, use_colnames=True)
rules = association_rules(frequent_item_sets, metric="confidence", min_threshold=confidence)

# Suporte do conjunto de itens frequentes 
support = frequent_item_sets.sort_values(by = ['support'], ascending = False)

# Regras de associação geradas
results = rules.sort_values(
    by = ['lift'], ascending = False).drop(['zhangs_metric', 'antecedent support', 'consequent support', 'leverage', 
                                            'conviction'],  axis = 1) 

# Gravação dos resultados para visualização do usuário

# Salva o Suporte do conjunto de itens frequentes em HTML para análise de ocorrências
support.to_html('support.html', index = False)

# Salva as regras de associação em HTML para análise do resultado
results.to_html('association_rules.html', index = False)

# %%
# Filtrar regras com poucos itens no antecedente e com suporte acima de 2%
results_few_items = results[results['antecedents'].apply(lambda x: len(x) <= 2)]

results_few_items = results_few_items[results_few_items['support'].apply(lambda x: x >= 0.02)]

# Ordenar para facilitar análise
results_few_items = results_few_items.sort_values(by='lift', ascending=False)

# Exportar para visualização
results_few_items.to_html('association_rules_few_antecedents.html', index=False)

# %% [markdown]
# ### Visualização dos resultados

# %%
# Lista de lista: conjunto de dados em formato de matriz
list_of_lists[0:10]
# Out:
# [['CALCADO KLIN TENIS FEMININO ALGODAO DOCE 115',
#   'CALCADO KLIN TENIS FEMININO ALGODAO DOCE 115',
#   'CALCADO KLIN SAPATILHA FEMININA ALGODAO DOCE 119'],
#  ['CALCADO KLIN MOCASSIM MASCULINO RECEM NASCIDO B001',
#   'CALCADO KLIN SANDALIA MASCULINA RECEM NASCIDO B016',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO B055',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO B073',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 059',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 063',
#   'CALCADO KLIN SANDALIA MASCULINA RECEM NASCIDO B012',
#   'CALCADO KLIN SANDALIA MASCULINA RECEM NASCIDO B014',
#   'CALCADO KLIN SAPATO FEMININA RECEM NASCIDO B040',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO B045',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO B072',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO B072',
#   'CALCADO KLIN MOCASSIM MASCULINO RECEM NASCIDO B009',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO B003',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO B036',
#   'CALCADO KLIN SANDALIA MASCULINA RECEM NASCIDO B025',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO B072',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO B065',
#   'CALCADO KLIN MOCASSIM MASCULINO RECEM NASCIDO B001',
#   'CALCADO KLIN TENIS  MASCULINA RECEM NASCIDO B019',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO B056'],
#  ['CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 054',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 056'],
#  ['MOCASSIM MASCULINO',
#   'MOCASSIM MASCULINO',
#   'SANDALIA CASUAL',
#   'SANDALIA CASUAL',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 311',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 308',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 264',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 299',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 267',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 092',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 413',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 427',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 427',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 427',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA034',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 091',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 092',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 097',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 097',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 324',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA032',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA034',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA032'],
#  ['CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 055',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 022',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 022',
#   'CALCADO KLIN SANDALIA MASCULINA RECEM NASCIDO 016',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 056',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 055',
#   'CALCADO KLIN SANDALIA MASCULINA RECEM NASCIDO 016',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 056'],
#  ['CALCADO KLIN SAPATILHA FEMININA ALGODAO DOCE 137',
#   'CALCADO KLIN BOTA FEMININA RECEM NASCIDO 409',
#   'CALCADO KLIN SAPATILHA FEMININA ALGODAO DOCE 137',
#   'CALCADO KLIN BOTA FEMININA RECEM NASCIDO 409',
#   'CALCADO KLIN SAPATILHA ALGODAO DOCE 140',
#   'CALCADO KLIN SAPATILHA ALGODAO DOCE 140',
#   'CALCADO KLIN SAPATILHA ALGODAO DOCE 140',
#   'CALCADO KLIN SAPATILHA ALGODAO DOCE 140',
#   'CALCADO KLIN TENIS FEMININO RECEM NASCIDO 401',
#   'CALCADO KLIN TENIS FEMININO RECEM NASCIDO 401',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 413',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 352',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 352',
#   'CALCADO KLIN TENIS FEMININO RECEM NASCIDO 410',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 413',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 439',
#   'CALCADO KLIN TENIS FEMININO RECEM NASCIDO 410',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 421',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 439',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 405',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 432',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 439',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 421',
#   'CALCADO KLIN SANDALIA MASCULINA RECEM NASCIDO 437',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 421',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 430',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA033',
#   'CALCADO KLIN SANDALIA MASCULINA RECEM NASCIDO 437',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 422',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA036',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA032',
#   'CALCADO KLIN SANDALIA MASCULINA RECEM NASCIDO 437',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA032',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 422',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA032',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 433',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA032',
#   'CALCADO KLIN BOTA FEMININA RECEM NASCIDO 409',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 435',
#   'CALCADO KLIN SAPATILHA FEMININA ALGODAO DOCE 137',
#   'CALCADO KLIN SAPATILHA FEMININA ALGODAO DOCE 137',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA034',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 352',
#   'CALCADO KLIN SAPATILHA ALGODAO DOCE 140',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA036',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 405',
#   'CALCADO KLIN TENIS FEMININO RECEM NASCIDO 417',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 405',
#   'CALCADO KLIN TENIS FEMININO RECEM NASCIDO 417',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 422',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 413',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 435',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 439',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA032',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 422',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA036',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 435',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 435',
#   'CALCADO KLIN BOTA FEMININA CRAVINHO BOTA036'],
#  ['CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 353',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 353',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 448',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 448',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 454',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 352',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 452',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 462',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 447',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 461',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 473',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 451',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 470',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 482',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 459',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 482',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 469',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 353',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 489',
#   'CALCADO KLIN SLEEP ON MASCULINO RECEM NASCIDO 487',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 450',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 477',
#   'CALCADO KLIN SAPATO MASCULINO ALGODAO DOCE 141',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 454',
#   'CALCADO KLIN SAPATO MASCULINO ALGODAO DOCE 151',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 485',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 462',
#   'CALCADO KLIN SAPATO MASCULINO ALGODAO DOCE 141',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 476',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 483',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 310',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 491',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 446',
#   'CALCADO KLIN SAPATO MASCULINO ALGODAO DOCE 151',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 308',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 451',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 456',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 446',
#   'CALCADO KLIN TENIS FEMININO RECEM NASCIDO 464',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 450',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 477',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 455',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 485',
#   'CALCADO KLIN SAPATILHA ALGODAO DOCE 140',
#   'CALCADO KLIN TENIS FEMININO RECEM NASCIDO 464',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 476',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 484',
#   'CALCADO KLIN SAPATILHA ALGODAO DOCE 140',
#   'CALCADO KLIN SAPATO MASCULINO ALGODAO DOCE 153'],
#  ['CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 425',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 432',
#   'CALCADO KLIN TENIS FEMININO RECEM NASCIDO 410',
#   'CALCADO KLIN SAPATO MASCULINO RECEM NASCIDO 432',
#   'CALCADO KLIN SANDALIA FEMININA RECEM NASCIDO 413'],
#  ['CALCADO KLIN MOCASSIM MASCULINO RECEM NASCIDO 106',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 104',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 152',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 067',
#   'CALCADO KLIN TENIS MASCULINO RECEM NASCIDO 110',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 149',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 064',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 143',
#   'CALCADO KLIN SANDALIA MASCULINO RECEM NASCIDO 104',
#   'CALCADO KLIN SAPATILHA FEMININA RECEM NASCIDO 150'],
#  ['CALCADO KLIN MOCASSIM MASCULINO CURUMIM 082',
#   'CALCADO KLIN MOCASSIM MASCULINO CURUMIM 083']]

# %%
# Data Frame: conjunto de dados em formato binário
df_encoded
# Out:
#       ALGODAO DOCE  ALPARGATAS RECEM NASCIDO FIT  BOTA  MASCULINA  \
# 0            False                         False            False
# 1            False                         False            False
# 2            False                         False            False
# 3            False                         False            False
# 4            False                         False            False
# ...            ...                           ...              ...
# 8540         False                         False            False
# 8541         False                         False            False
# 8542         False                         False            False
# 8543         False                         False            False
# 8544         False                         False            False
#
#       BOTA CASUAL MASCULINA  BOTA FEMININA  BOTA FEMININO  BOTA MASCULINA  \
# 0                     False          False          False           False
# 1                     False          False          False           False
# 2                     False          False          False           False
# 3                     False          False          False           False
# 4                     False          False          False           False
# ...                     ...            ...            ...             ...
# 8540                  False          False          False           False
# 8541                  False          False          False           False
# 8542                  False          False          False           False
# 8543                  False          False          False           False
# 8544                  False          False          False           False
#
#       CALCADO  KLIN SAPATO MASCULINO RECEM NASCIDO 188  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 8540                                             False
# 8541                                             False
# 8542                                             False
# 8543                                             False
# 8544                                             False
#
#       CALCADO DELICAT MOCASSIM FEMININO 020  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ...                                     ...
# 8540                                  False
# 8541                                  False
# 8542                                  False
# 8543                                  False
# 8544                                  False
#
#       CALCADO DELICAT MOCASSIM FEMININO 021  ...  \
# 0                                     False  ...
# 1                                     False  ...
# 2                                     False  ...
# 3                                     False  ...
# 4                                     False  ...
# ...                                     ...  ...
# 8540                                  False  ...
# 8541                                  False  ...
# 8542                                  False  ...
# 8543                                  False  ...
# 8544                                  False  ...
#
#       TENIS MASCULINO PRIMEIROS PASSOS 013  TENIS RECEM NASCIDO FIT  \
# 0                                    False                    False
# 1                                    False                    False
# 2                                    False                    False
# 3                                    False                    False
# 4                                    False                    False
# ...                                    ...                      ...
# 8540                                 False                    False
# 8541                                 False                    False
# 8542                                 False                    False
# 8543                                 False                    False
# 8544                                 False                    False
#
#       TENIS SAMEKA INFANTIL FEMININO 001  TENIS SAMEKA INFANTIL FEMININO 002  \
# 0                                  False                               False
# 1                                  False                               False
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
# ...                                  ...                                 ...
# 8540                               False                               False
# 8541                               False                               False
# 8542                               False                               False
# 8543                               False                               False
# 8544                               False                               False
#
#       TENIS SAMEKA INFANTIL FEMININO 003  TENIS SAMEKA INFANTIL MASCULINO 001  \
# 0                                  False                                False
# 1                                  False                                False
# 2                                  False                                False
# 3                                  False                                False
# 4                                  False                                False
# ...                                  ...                                  ...
# 8540                               False                                False
# 8541                               False                                False
# 8542                               False                                False
# 8543                               False                                False
# 8544                               False                                False
#
#       TENIS SAMEKA INFANTIL MASCULINO 003  TENIS UNISSEX PRIMEIROS PASSOS 001  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
# 3                                   False                               False
# 4                                   False                               False
# ...                                   ...                                 ...
# 8540                                False                               False
# 8541                                False                               False
# 8542                                False                               False
# 8543                                False                               False
# 8544                                False                               False
#
#       TENIS UNISSEX PRIMEIROS PASSOS 002  TENIS UNISSEX PRIMEIROS PASSOS 003
# 0                                  False                               False
# 1                                  False                               False
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
# ...                                  ...                                 ...
# 8540                               False                               False
# 8541                               False                               False
# 8542                               False                               False
# 8543                               False                               False
# 8544                               False                               False
#
# [8545 rows x 1251 columns]

# %%
# Suporte do conjunto de itens frequentes
support.count()
# Out:
# support     498
# itemsets    498
# dtype: int64

# %%
# Resultados com suporte 0.01, confiança de 0.85 sem filtro de antecedentes
results.count()
# Out:
# antecedents         37
# consequents         37
# support             37
# confidence          37
# lift                37
# representativity    37
# jaccard             37
# certainty           37
# kulczynski          37
# dtype: int64

# %%
# Resultados com suporte filtrado de 0.02, confiança de 0.85 com filtro de antecedentes <= 2
results_few_items.count()
# Out:
# antecedents         5
# consequents         5
# support             5
# confidence          5
# lift                5
# representativity    5
# jaccard             5
# certainty           5
# kulczynski          5
# dtype: int64
